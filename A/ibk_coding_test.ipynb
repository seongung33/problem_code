# %% [markdown]
# # 치트키 꼭 기억하기
# ```py
# # 어떤 함수가 있는가
# print(dir(pd))
# print(dir(scaler))
# # 파라미터가 기억 안 날때
# help(RandomForestClassifier)
# # 사이킷런 내부 패키지 확인용
# print(sklearn.__all__)
#
# # 너무 길어서 다 안나오면?
# print(", ".join(dir(sklearn.__all__)))
# ```

# %% [markdown]
# # 판다스 and 사이킷런

# %%
# 날짜 변경
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
print(sum(df['date'].dt.month == 12))

# %%
# 결측치 처리
X_train['bmi'] = X_train['bmi'].fillna(X_train['bmi'].median())
X_test['bmi'] = X_test['bmi'].fillna(X_train['bmi'].median())
# .median or mean or mode -> mode: 최빈값

# %%
import pandas as pd
# 원 핫 인코딩
cols = X_train.select_dtypes(include = object).columns
X_train = pd.get_dummies(X_train, columns= cols)
# 라벨 인코딩
X_train['age'] = X_train['age'].apply(lambda x: x//10)

# %%
# 정규화
from sklearn.preprocessing import StandardScaler 
scalar = StandardScaler()
X_train['bmi'] = scalar.fit_transform(X_train[['bmi']])
X_test['bmi'] = scalar.transform(X_test[['bmi']])

# 만약 여러개를 넣는다면 
cols = train.select_dtypes(exclude = 'object').columns # -> 오브젝트가 아닌 것들만 넣기
cols = cols.drop('y')
# 지금은 인덱스라는 객체 안에 들어가있다 이를 제거하기 위해
cols.tolist() # -> 리스트 형태로 위에 적용 가능
X_train[cols] = scaler.fit_transform(X_train[cols])

# %%
# train_test_split
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y, test_size=0.2)

# %% [markdown]
# ## 사이킷런 모델들

# %% [markdown]
# ### 회귀

# %%
# 랜포 
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42, )
rf.fit(X_tr, y_tr)
pred = rf.predict(X_val)

# %%
# xgb부스트
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(X_tr, y_tr)
pred = xgb.predict(X_val)

# %%
# 검정
from sklearn.metrics import mean_squared_error # 이외에도 r2_score, mean_absolute_error 검정 있음
def rmse(y_tr, pred):
    return np.sqrt(mean_squared_error(y_tr, pred))

# %% [markdown]
# ## 분류

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_tr, target)
predictions = model.predict_proba(test)
# 정답이 1일 확률을 구하는 문제라면?
pred = predictions[:, 1]

# %%
# XGB
from xgboost import XGBClassifier
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(X_tr, y_tr)
pred = model.predict_proba(X_val)[:, 1]
# 정

# %%
# roc-auc 검정
from sklearn.metrics import roc_auc_score
roc_auc_score(y_val, val_pred)
